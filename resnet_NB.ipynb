# %%
import datetime
import torchvision as tv
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
from custom_dataset import Chest3Dataset, CovidDataset
from settings import IMG_SIZE, ALL_ARCHITECTURES
from model_metadata import create_model_dir, save_common_info, plot_progress, get_model_summary

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)

def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

class LambdaLayer(nn.Module):
    """
      Identity mapping between ResNet blocks with diffrenet size feature map
    """
    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1, option='A'):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, padding=0)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            if option == 'A':
                """
                For CIFAR10 experiment, ResNet paper uses option A.
                """
                self.shortcut = LambdaLayer(lambda x:
                                            F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, out_channels//4, out_channels//4), "constant", 0))

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out
# Out:
# cuda

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels = 64
        self.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3)
        self.bn1 = nn.BatchNorm2d(64)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)

        self.linear = nn.Linear(256* block.expansion, num_classes)
        self.apply(_weights_init)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.maxpool(out)

        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)

        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def resnet20():
    return ResNet(BasicBlock, [3, 3, 3])


def resnet32():
    return ResNet(BasicBlock, [5, 5, 5])


def resnet44():
    return ResNet(BasicBlock, [7, 7, 7])


def resnet56():
    return ResNet(BasicBlock, [9, 9, 9])

# %%
class MyResNetArgs:
   """
    Passing the hyperparameters to the model
   """
   def __init__(self, arch='resnet32' ,epochs=100, start_epoch=0, batch_size=128, lr=0.1, momentum=0.9, weight_decay=1e-4):
        
        self.weight_decay = weight_decay
        self.momentum = momentum 
        self.lr = lr #Learning rate
        self.batch_size = batch_size 
        self.start_epoch = start_epoch
        self.epochs = epochs
        self.arch = arch #ResNet model


def train(train_loader, model, criterion, optimizer, epoch):
    """
        Run one train epoch
    """
    print('train')
    losses = AverageMeter()
    top1 = AverageMeter()

    # switch to train mode
    model.train()

    for i, (input, target) in enumerate(train_loader):
        input_var = input.float().cuda()
        target_var = target.cuda()

        # compute output
        output = model(input_var)
        loss = criterion(output, target_var)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        output = output.float()
        loss = loss.float()
        # measure accuracy and record loss
        acc = accuracy(output.data, target_var)[0]
        losses.update(loss.item(), input.size(0))
        top1.update(acc.item(), input.size(0))

    print(f'Epoch: [{ epoch}]\t Loss {losses.val:.4f} ({losses.avg:.4f})\t acc {top1.val:.3f} ({top1.avg:.3f})')
    return top1.avg, losses.avg
       

def testing(val_loader, model, criterion):
    """
    Run evaluation
    """
    losses = AverageMeter()
    top1 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    with torch.no_grad():
        for i, (input, target) in enumerate(val_loader):
            input_var = input.float().cuda()
            target_var = target.cuda()

            # compute output
            output = model(input_var)
            loss = criterion(output, target_var)

            output = output.float()
            loss = loss.float()

            # measure accuracy and record loss and acc
            acc = accuracy(output.data, target_var)[0]
            losses.update(loss.item(), input.size(0))
            top1.update(acc.item(), input.size(0))


    print(f'Test\t  accuracy: {top1.avg:.3f} (Err: {losses.avg:.3f} )\n')

    return top1.avg, losses.avg

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def accuracy(output, target, topk=1):
    batch_size = target.size(0)

    _, pred = output.topk(topk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    correct_k = correct[:topk].reshape(-1).float().sum(0, keepdim=True)
    res.append(correct_k.mul_(100.0 / batch_size))
    return res



#train_loader = DataLoader(Chest3Dataset('data/chest_xray_3/train.csv', 'data/chest_xray_3', special_transform=transforms.Compose([tv.transforms.Grayscale(num_output_channels=1)]), transform=transforms.Compose([transforms.RandomHorizontalFlip(), transforms.RandomVerticalFlip(), transforms.RandomRotation(.05)])), batch_size=128, shuffle=True, num_workers=2, pin_memory=True)
#test_loader = DataLoader(Chest3Dataset('data/chest_xray_3/test.csv', 'data/chest_xray_3', special_transform=transforms.Compose([tv.transforms.Grayscale(num_output_channels=1)])), batch_size=128, shuffle=False, num_workers=2, pin_memory=True)

# TODO: Don't forget to change this variable {DATASET} to the dataset name you are training on 
train_loader = DataLoader(CovidDataset('data/covid_data/train.csv', 'data/covid_data/train', special_transform=transforms.Compose([tv.transforms.Grayscale(num_output_channels=1)])), batch_size=128, shuffle=True, pin_memory=True)
test_loader = DataLoader(CovidDataset('data/covid_data/test.csv', 'data/covid_data/test', special_transform=transforms.Compose([tv.transforms.Grayscale(num_output_channels=1)])), batch_size=128, shuffle=False, pin_memory=True)


def main(model_path, model_name):
    print('main')
    best_acc = 0
    global args
    args=MyResNetArgs(model_name)
    model = globals()[model_name]()

    model.cuda()

    # define loss function (criterion) and optimizer
    criterion = nn.CrossEntropyLoss().cuda()

    optimizer = torch.optim.SGD(model.parameters(), args.lr, momentum=args.momentum,
                                weight_decay=args.weight_decay)

    lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer,
                                                        milestones=[100, 150], last_epoch=args.start_epoch - 1)

    print('Training {} model'.format(args.arch))
    test_accs, test_losses = [], []
    train_accs, train_losses = [], []
    for epoch in range(args.start_epoch, args.epochs):

        train_acc, train_loss = train(train_loader, model, criterion, optimizer, epoch)
        lr_scheduler.step()

        train_accs.append(train_acc)
        train_losses.append(train_loss)

        # evaluate on validation set
        acc, loss = testing(test_loader, model, criterion)
        test_accs.append(acc)
        test_losses.append(loss)
        if acc > best_acc:
            best_acc = acc
            # save model 
            torch.save(model.state_dict(), f'{model_path}/model.pth')

    return {"best_acc": max(test_accs), "test_accs":test_accs, "test_losses": test_losses, "train_acss": train_accs, "train_losses": train_losses}

# %%
if __name__ == '__main__':
    models_info = {}
    for architecture in ALL_ARCHITECTURES:
       model_path = create_model_dir('results_resnet')
       get_model_summary(model_path, globals()[architecture]())
       start = datetime.datetime.now() 
       model_info = main(model_path, architecture)
       end = datetime.datetime.now()
       models_info[architecture] = model_info
       save_common_info(model_path, args, model_info, start, end)
       plot_progress(model_path, "Testing Accuracy", architecture, model_info["test_accs"])
       plot_progress(model_path, "Training Accuracy", architecture, model_info["train_acss"])
       plot_progress(model_path, "Testing Loss", architecture, model_info["test_losses"])
       plot_progress(model_path, "Training Loss", architecture, model_info["train_losses"])
# Out:
# main
# Training resnet44 model
# train
# Epoch: [0]	 Loss 0.2728 (1.2466)	 acc 87.500 (76.652)
# Test	  accuracy: 67.000 (Err: 0.656 )
#
# train
# Epoch: [1]	 Loss 0.4279 (0.2734)	 acc 85.417 (87.994)
# Test	  accuracy: 52.000 (Err: 1.120 )
#
# train
# Epoch: [2]	 Loss 0.1591 (0.2179)	 acc 89.583 (91.002)
# Test	  accuracy: 77.250 (Err: 0.537 )
#
# train
# Epoch: [3]	 Loss 0.1727 (0.1940)	 acc 93.750 (92.088)
# Test	  accuracy: 69.250 (Err: 1.075 )
#
# train
# Epoch: [4]	 Loss 0.2324 (0.1672)	 acc 93.750 (93.269)
# Test	  accuracy: 89.000 (Err: 0.281 )
#
# train
# Epoch: [5]	 Loss 0.1679 (0.1576)	 acc 91.667 (93.651)
# Test	  accuracy: 81.000 (Err: 0.517 )
#
# train
# Epoch: [6]	 Loss 0.2254 (0.1408)	 acc 93.750 (94.573)
# Test	  accuracy: 61.500 (Err: 1.137 )
#
# train
# Epoch: [7]	 Loss 0.0804 (0.1295)	 acc 95.833 (94.994)
# Test	  accuracy: 89.250 (Err: 0.275 )
#
# train
# Epoch: [8]	 Loss 0.1273 (0.1184)	 acc 93.750 (95.359)
# Test	  accuracy: 83.750 (Err: 0.458 )
#
# train
# Epoch: [9]	 Loss 0.0422 (0.1053)	 acc 100.000 (95.939)
# Test	  accuracy: 76.000 (Err: 1.020 )
#
# train
# Epoch: [10]	 Loss 0.1160 (0.0972)	 acc 91.667 (96.264)
# Test	  accuracy: 73.750 (Err: 0.661 )
#
# train
# Epoch: [11]	 Loss 0.1558 (0.0880)	 acc 95.833 (96.557)
# Test	  accuracy: 83.750 (Err: 0.552 )
#
# train
# Epoch: [12]	 Loss 0.2227 (0.0852)	 acc 89.583 (96.748)
# Test	  accuracy: 57.250 (Err: 1.905 )
#
# train
# Epoch: [13]	 Loss 0.0800 (0.0774)	 acc 95.833 (97.084)
# Test	  accuracy: 88.500 (Err: 0.410 )
#
# train
# Epoch: [14]	 Loss 0.1553 (0.0662)	 acc 97.917 (97.433)
# Test	  accuracy: 87.250 (Err: 0.386 )
#
# train
# Epoch: [15]	 Loss 0.0414 (0.0615)	 acc 97.917 (97.683)
# Test	  accuracy: 83.000 (Err: 0.723 )
#
# train
# Epoch: [16]	 Loss 0.0240 (0.0554)	 acc 100.000 (97.913)
# Test	  accuracy: 71.500 (Err: 1.433 )
#
# train
# Epoch: [17]	 Loss 0.0804 (0.0512)	 acc 97.917 (98.065)
# Test	  accuracy: 90.000 (Err: 0.290 )
#
# train
# Epoch: [18]	 Loss 0.0502 (0.0457)	 acc 97.917 (98.351)
# Test	  accuracy: 87.500 (Err: 0.425 )
#
# train
# Epoch: [19]	 Loss 0.0236 (0.0424)	 acc 100.000 (98.420)
# Test	  accuracy: 86.000 (Err: 0.568 )
#
# train
# Epoch: [20]	 Loss 0.0332 (0.0435)	 acc 100.000 (98.331)
# Test	  accuracy: 82.000 (Err: 0.956 )
#
# train
# Epoch: [21]	 Loss 0.0092 (0.0371)	 acc 100.000 (98.611)
# Test	  accuracy: 78.250 (Err: 0.848 )
#
# train
# Epoch: [22]	 Loss 0.0109 (0.0320)	 acc 100.000 (98.756)
# Test	  accuracy: 84.750 (Err: 0.639 )
#
# train
# Epoch: [23]	 Loss 0.0072 (0.0357)	 acc 100.000 (98.608)
# Test	  accuracy: 71.000 (Err: 1.449 )
#
# train
# Epoch: [24]	 Loss 0.0116 (0.0332)	 acc 100.000 (98.739)
# Test	  accuracy: 65.750 (Err: 1.836 )
#
# train
# Epoch: [25]	 Loss 0.0270 (0.0321)	 acc 100.000 (98.825)
# Test	  accuracy: 81.000 (Err: 0.811 )
#
# train
# Epoch: [26]	 Loss 0.0012 (0.0288)	 acc 100.000 (98.934)
# Test	  accuracy: 88.000 (Err: 0.519 )
#
# train
# Epoch: [27]	 Loss 0.0474 (0.0283)	 acc 97.917 (98.980)
# Test	  accuracy: 89.750 (Err: 0.451 )
#
# train
# Epoch: [28]	 Loss 0.0065 (0.0249)	 acc 100.000 (99.095)
# Test	  accuracy: 87.750 (Err: 0.560 )
#
# train
# Epoch: [29]	 Loss 0.0375 (0.0241)	 acc 97.917 (99.128)
# Test	  accuracy: 70.000 (Err: 2.004 )
#
# train
# Epoch: [30]	 Loss 0.0248 (0.0257)	 acc 97.917 (99.088)
# Test	  accuracy: 89.750 (Err: 0.511 )
#
# train
# Epoch: [31]	 Loss 0.0121 (0.0286)	 acc 100.000 (98.957)
# Test	  accuracy: 92.000 (Err: 0.347 )
#
# train
# Epoch: [32]	 Loss 0.2444 (0.0208)	 acc 93.750 (99.276)
# Test	  accuracy: 83.250 (Err: 0.898 )
#
# train
# Epoch: [33]	 Loss 0.0097 (0.0268)	 acc 100.000 (99.032)
# Test	  accuracy: 85.750 (Err: 0.515 )
#
# train
# Epoch: [34]	 Loss 0.0032 (0.0261)	 acc 100.000 (99.072)
# Test	  accuracy: 91.500 (Err: 0.348 )
#
# train
# Epoch: [35]	 Loss 0.0017 (0.0190)	 acc 100.000 (99.306)
# Test	  accuracy: 87.250 (Err: 0.623 )
#
# train
# Epoch: [36]	 Loss 0.0015 (0.0222)	 acc 100.000 (99.243)
# Test	  accuracy: 79.000 (Err: 1.011 )
#
# train
# Epoch: [37]	 Loss 0.0088 (0.0204)	 acc 100.000 (99.266)
# Test	  accuracy: 76.750 (Err: 1.659 )
#
# train
# Epoch: [38]	 Loss 0.0018 (0.0230)	 acc 100.000 (99.171)
# Test	  accuracy: 88.000 (Err: 0.499 )
#
# train
# Epoch: [39]	 Loss 0.0076 (0.0181)	 acc 100.000 (99.355)
# Test	  accuracy: 57.500 (Err: 3.491 )
#
# train
# Epoch: [40]	 Loss 0.0380 (0.0213)	 acc 97.917 (99.227)
# Test	  accuracy: 67.250 (Err: 1.439 )
#
# train
# Epoch: [41]	 Loss 0.1277 (0.0213)	 acc 93.750 (99.236)
# Test	  accuracy: 77.250 (Err: 1.882 )
#
# train
# Epoch: [42]	 Loss 0.0975 (0.0196)	 acc 95.833 (99.319)
# Test	  accuracy: 89.000 (Err: 0.554 )
#
# train
# Epoch: [43]	 Loss 0.0095 (0.0249)	 acc 100.000 (99.108)
# Test	  accuracy: 90.250 (Err: 0.554 )
#
# train
# Epoch: [44]	 Loss 0.0020 (0.0206)	 acc 100.000 (99.266)
# Test	  accuracy: 83.500 (Err: 0.749 )
#
# train
# Epoch: [45]	 Loss 0.0010 (0.0177)	 acc 100.000 (99.388)
# Test	  accuracy: 90.750 (Err: 0.348 )
#
# train
# Epoch: [46]	 Loss 0.0699 (0.0182)	 acc 95.833 (99.299)
# Test	  accuracy: 90.000 (Err: 0.395 )
#
# train
# Epoch: [47]	 Loss 0.0012 (0.0163)	 acc 100.000 (99.385)
# Test	  accuracy: 90.750 (Err: 0.381 )
#
# train
# Epoch: [48]	 Loss 0.0051 (0.0220)	 acc 100.000 (99.217)
# Test	  accuracy: 92.750 (Err: 0.315 )
#
# train
# Epoch: [49]	 Loss 0.0075 (0.0198)	 acc 100.000 (99.279)
# Test	  accuracy: 69.000 (Err: 1.531 )
#
# train
# Epoch: [50]	 Loss 0.0008 (0.0138)	 acc 100.000 (99.562)
# Test	  accuracy: 93.250 (Err: 0.298 )
#
# train
# Epoch: [51]	 Loss 0.0186 (0.0196)	 acc 100.000 (99.338)
# Test	  accuracy: 91.000 (Err: 0.370 )
#
# train
# Epoch: [52]	 Loss 0.0551 (0.0235)	 acc 95.833 (99.200)
# Test	  accuracy: 82.000 (Err: 0.724 )
#
# train
# Epoch: [53]	 Loss 0.0482 (0.0205)	 acc 97.917 (99.266)
# Test	  accuracy: 85.500 (Err: 0.517 )
#
# train
# Epoch: [54]	 Loss 0.0063 (0.0265)	 acc 100.000 (99.006)
# Test	  accuracy: 87.750 (Err: 0.478 )
#
# train
# Epoch: [55]	 Loss 0.0382 (0.0161)	 acc 97.917 (99.427)
# Test	  accuracy: 85.000 (Err: 0.982 )
#
# train
# Epoch: [56]	 Loss 0.0088 (0.0177)	 acc 100.000 (99.368)
# Test	  accuracy: 86.500 (Err: 0.620 )
#
# train
# Epoch: [57]	 Loss 0.0084 (0.0203)	 acc 100.000 (99.283)
# Test	  accuracy: 81.500 (Err: 1.326 )
#
# train
# Epoch: [58]	 Loss 0.0016 (0.0162)	 acc 100.000 (99.444)
# Test	  accuracy: 92.250 (Err: 0.429 )
#
# train
# Epoch: [59]	 Loss 0.0029 (0.0162)	 acc 100.000 (99.394)
# Test	  accuracy: 89.250 (Err: 0.473 )
#
# train
# Epoch: [60]	 Loss 0.0349 (0.0133)	 acc 97.917 (99.546)
# Test	  accuracy: 88.500 (Err: 0.661 )
#
# train
# Epoch: [61]	 Loss 0.0076 (0.0213)	 acc 100.000 (99.197)
# Test	  accuracy: 71.250 (Err: 2.458 )
#
# train
# Epoch: [62]	 Loss 0.0250 (0.0216)	 acc 97.917 (99.197)
# Test	  accuracy: 80.500 (Err: 0.973 )
#
# train
# Epoch: [63]	 Loss 0.1780 (0.0209)	 acc 95.833 (99.246)
# Test	  accuracy: 83.250 (Err: 0.567 )
#
# train
# Epoch: [64]	 Loss 0.1022 (0.0143)	 acc 97.917 (99.467)
# Test	  accuracy: 64.750 (Err: 2.323 )
#
# train
# Epoch: [65]	 Loss 0.0131 (0.0239)	 acc 100.000 (99.194)
# Test	  accuracy: 82.500 (Err: 0.898 )
#
# train
# Epoch: [66]	 Loss 0.0232 (0.0161)	 acc 97.917 (99.421)
# Test	  accuracy: 62.750 (Err: 1.967 )
#
# train
# Epoch: [67]	 Loss 0.0026 (0.0210)	 acc 100.000 (99.259)
# Test	  accuracy: 79.250 (Err: 0.889 )
#
# train
# Epoch: [68]	 Loss 0.0006 (0.0166)	 acc 100.000 (99.404)
# Test	  accuracy: 66.000 (Err: 1.983 )
#
# train
# Epoch: [69]	 Loss 0.0053 (0.0171)	 acc 100.000 (99.375)
# Test	  accuracy: 82.750 (Err: 0.786 )
#
# train
# Epoch: [70]	 Loss 0.0368 (0.0189)	 acc 97.917 (99.322)
# Test	  accuracy: 89.250 (Err: 0.457 )
#
# train
# Epoch: [71]	 Loss 0.0031 (0.0224)	 acc 100.000 (99.259)
# Test	  accuracy: 79.750 (Err: 0.925 )
#
# train
# Epoch: [72]	 Loss 0.0028 (0.0159)	 acc 100.000 (99.467)
# Test	  accuracy: 69.250 (Err: 1.676 )
#
# train
# Epoch: [73]	 Loss 0.0904 (0.0144)	 acc 97.917 (99.500)
# Test	  accuracy: 91.750 (Err: 0.358 )
#
# train
# Epoch: [74]	 Loss 0.0155 (0.0255)	 acc 100.000 (99.088)
# Test	  accuracy: 73.000 (Err: 2.387 )
#
# train
# Epoch: [75]	 Loss 0.0032 (0.0139)	 acc 100.000 (99.539)
# Test	  accuracy: 91.500 (Err: 0.478 )
#
# train
# Epoch: [76]	 Loss 0.0070 (0.0190)	 acc 100.000 (99.312)
# Test	  accuracy: 81.000 (Err: 0.942 )
#
# train
# Epoch: [77]	 Loss 0.0031 (0.0189)	 acc 100.000 (99.335)
# Test	  accuracy: 85.000 (Err: 0.805 )
#
# train
# Epoch: [78]	 Loss 0.0156 (0.0176)	 acc 100.000 (99.348)
# Test	  accuracy: 90.750 (Err: 0.326 )
#
# train
# Epoch: [79]	 Loss 0.0536 (0.0169)	 acc 95.833 (99.365)
# Test	  accuracy: 83.250 (Err: 0.636 )
#
# train
# Epoch: [80]	 Loss 0.0135 (0.0191)	 acc 100.000 (99.306)
# Test	  accuracy: 90.500 (Err: 0.423 )
#
# train
# Epoch: [81]	 Loss 0.0042 (0.0179)	 acc 100.000 (99.362)
# Test	  accuracy: 85.250 (Err: 0.805 )
#
# train
# Epoch: [82]	 Loss 0.0273 (0.0180)	 acc 97.917 (99.375)
# Test	  accuracy: 79.250 (Err: 1.567 )
#
# train
# Epoch: [83]	 Loss 0.0006 (0.0163)	 acc 100.000 (99.450)
# Test	  accuracy: 89.000 (Err: 0.413 )
#
# train
# Epoch: [84]	 Loss 0.0086 (0.0162)	 acc 100.000 (99.417)
# Test	  accuracy: 82.250 (Err: 0.791 )
#
# train
# Epoch: [85]	 Loss 0.0002 (0.0156)	 acc 100.000 (99.460)
# Test	  accuracy: 88.250 (Err: 0.529 )
#
# train
# Epoch: [86]	 Loss 0.0247 (0.0175)	 acc 97.917 (99.348)
# Test	  accuracy: 88.750 (Err: 0.424 )
#
# train
# Epoch: [87]	 Loss 0.0012 (0.0140)	 acc 100.000 (99.473)
# Test	  accuracy: 88.500 (Err: 0.421 )
#
# train
# Epoch: [88]	 Loss 0.0664 (0.0138)	 acc 95.833 (99.543)
# Test	  accuracy: 88.250 (Err: 0.593 )
#
# train
# Epoch: [89]	 Loss 0.0081 (0.0152)	 acc 100.000 (99.506)
# Test	  accuracy: 76.250 (Err: 2.075 )
#
# train
# Epoch: [90]	 Loss 0.0018 (0.0224)	 acc 100.000 (99.204)
# Test	  accuracy: 93.500 (Err: 0.361 )
#
# train
# Epoch: [91]	 Loss 0.0256 (0.0181)	 acc 97.917 (99.375)
# Test	  accuracy: 81.250 (Err: 0.972 )
#
# train
# Epoch: [92]	 Loss 0.0429 (0.0125)	 acc 97.917 (99.533)
# Test	  accuracy: 83.750 (Err: 0.944 )
#
# train
# Epoch: [93]	 Loss 0.0338 (0.0195)	 acc 97.917 (99.296)
# Test	  accuracy: 83.750 (Err: 0.915 )
#
# train
# Epoch: [94]	 Loss 0.0515 (0.0159)	 acc 97.917 (99.431)
# Test	  accuracy: 68.500 (Err: 1.700 )
#
# train
# Epoch: [95]	 Loss 0.0039 (0.0170)	 acc 100.000 (99.394)
# Test	  accuracy: 82.750 (Err: 0.776 )
#
# train
# Epoch: [96]	 Loss 0.0448 (0.0175)	 acc 95.833 (99.352)
# Test	  accuracy: 86.500 (Err: 0.488 )
#
# train
# Epoch: [97]	 Loss 0.0155 (0.0211)	 acc 100.000 (99.236)
# Test	  accuracy: 76.750 (Err: 1.754 )
#
# train
# Epoch: [98]	 Loss 0.0004 (0.0096)	 acc 100.000 (99.684)
# Test	  accuracy: 92.750 (Err: 0.347 )
#
# train
# Epoch: [99]	 Loss 0.0285 (0.0166)	 acc 97.917 (99.401)
# Test	  accuracy: 85.500 (Err: 0.708 )
#
# main
# Training resnet56 model
# train
# Epoch: [0]	 Loss 0.1919 (1.9594)	 acc 95.833 (76.797)
# Test	  accuracy: 77.000 (Err: 0.566 )
#
# train
# Epoch: [1]	 Loss 0.2260 (0.2507)	 acc 89.583 (89.636)
# Test	  accuracy: 87.000 (Err: 0.349 )
#
# train
# Epoch: [2]	 Loss 0.1636 (0.2036)	 acc 91.667 (91.864)
# Test	  accuracy: 77.250 (Err: 0.489 )
#
# train
# Epoch: [3]	 Loss 0.3712 (0.1769)	 acc 87.500 (93.046)
# Test	  accuracy: 84.000 (Err: 0.388 )
#
# train
# Epoch: [4]	 Loss 0.2506 (0.1588)	 acc 93.750 (93.635)
# Test	  accuracy: 87.250 (Err: 0.365 )
#
# train
# Epoch: [5]	 Loss 0.1762 (0.1436)	 acc 93.750 (94.408)
# Test	  accuracy: 82.500 (Err: 0.408 )
#
# train
# Epoch: [6]	 Loss 0.2783 (0.1281)	 acc 89.583 (95.083)
# Test	  accuracy: 88.250 (Err: 0.338 )
#
# train
# Epoch: [7]	 Loss 0.1099 (0.1225)	 acc 95.833 (95.267)
# Test	  accuracy: 86.000 (Err: 0.331 )
#
# train
# Epoch: [8]	 Loss 0.3182 (0.1074)	 acc 83.333 (95.929)
# Test	  accuracy: 85.250 (Err: 0.304 )
#
# train
# Epoch: [9]	 Loss 0.0584 (0.0946)	 acc 95.833 (96.264)
# Test	  accuracy: 87.500 (Err: 0.321 )
#
# train
# Epoch: [10]	 Loss 0.1422 (0.0827)	 acc 91.667 (96.738)
# Test	  accuracy: 89.000 (Err: 0.309 )
#
# train
# Epoch: [11]	 Loss 0.2715 (0.0791)	 acc 87.500 (96.916)
# Test	  accuracy: 88.500 (Err: 0.322 )
#
# train
# Epoch: [12]	 Loss 0.0698 (0.0676)	 acc 97.917 (97.446)
# Test	  accuracy: 85.250 (Err: 0.463 )
#
# train
# Epoch: [13]	 Loss 0.1236 (0.0649)	 acc 93.750 (97.548)
# Test	  accuracy: 85.500 (Err: 0.418 )
#
# train
# Epoch: [14]	 Loss 0.0525 (0.0578)	 acc 97.917 (97.805)
# Test	  accuracy: 81.250 (Err: 0.593 )
#
# train
# Epoch: [15]	 Loss 0.0572 (0.0513)	 acc 97.917 (98.101)
# Test	  accuracy: 82.500 (Err: 0.531 )
#
# train
# Epoch: [16]	 Loss 0.0220 (0.0520)	 acc 100.000 (98.002)
# Test	  accuracy: 89.250 (Err: 0.383 )
#
# train
# Epoch: [17]	 Loss 0.0148 (0.0446)	 acc 100.000 (98.279)
# Test	  accuracy: 88.500 (Err: 0.432 )
#
# train
# Epoch: [18]	 Loss 0.1050 (0.0405)	 acc 91.667 (98.473)
# Test	  accuracy: 86.500 (Err: 0.438 )
#
# train
# Epoch: [19]	 Loss 0.0021 (0.0393)	 acc 100.000 (98.483)
# Test	  accuracy: 88.500 (Err: 0.357 )
#
# train
# Epoch: [20]	 Loss 0.0435 (0.0348)	 acc 97.917 (98.670)
# Test	  accuracy: 86.750 (Err: 0.417 )
#
# train
# Epoch: [21]	 Loss 0.0581 (0.0327)	 acc 95.833 (98.818)
# Test	  accuracy: 87.250 (Err: 0.498 )
#
# train
# Epoch: [22]	 Loss 0.0116 (0.0316)	 acc 100.000 (98.789)
# Test	  accuracy: 80.750 (Err: 0.750 )
#
# train
# Epoch: [23]	 Loss 0.0443 (0.0272)	 acc 97.917 (99.072)
# Test	  accuracy: 80.500 (Err: 0.700 )
#
# train
# Epoch: [24]	 Loss 0.0124 (0.0272)	 acc 100.000 (98.996)
# Test	  accuracy: 86.500 (Err: 0.510 )
#
# train
# Epoch: [25]	 Loss 0.0748 (0.0228)	 acc 95.833 (99.246)
# Test	  accuracy: 86.750 (Err: 0.452 )
#
# train
# Epoch: [26]	 Loss 0.0055 (0.0259)	 acc 100.000 (99.055)
# Test	  accuracy: 88.250 (Err: 0.471 )
#
# train
# Epoch: [27]	 Loss 0.0083 (0.0241)	 acc 100.000 (99.141)
# Test	  accuracy: 86.250 (Err: 0.523 )
#
# train
# Epoch: [28]	 Loss 0.0954 (0.0274)	 acc 93.750 (99.016)
# Test	  accuracy: 86.750 (Err: 0.511 )
#
# train
# Epoch: [29]	 Loss 0.0082 (0.0247)	 acc 100.000 (99.108)
# Test	  accuracy: 87.500 (Err: 0.496 )
#
# train
# Epoch: [30]	 Loss 0.0249 (0.0228)	 acc 97.917 (99.151)
# Test	  accuracy: 87.250 (Err: 0.458 )
#
# train
# Epoch: [31]	 Loss 0.0008 (0.0162)	 acc 100.000 (99.411)
# Test	  accuracy: 82.000 (Err: 0.772 )
#
# train
# Epoch: [32]	 Loss 0.0015 (0.0257)	 acc 100.000 (99.032)
# Test	  accuracy: 79.500 (Err: 0.746 )
#
# train
# Epoch: [33]	 Loss 0.0067 (0.0183)	 acc 100.000 (99.358)
# Test	  accuracy: 87.000 (Err: 0.535 )
#
# train
# Epoch: [34]	 Loss 0.0919 (0.0215)	 acc 97.917 (99.233)
# Test	  accuracy: 87.500 (Err: 0.427 )
#
# train
# Epoch: [35]	 Loss 0.0072 (0.0188)	 acc 100.000 (99.312)
# Test	  accuracy: 90.750 (Err: 0.427 )
#
# train
# Epoch: [36]	 Loss 0.0177 (0.0208)	 acc 97.917 (99.273)
# Test	  accuracy: 81.000 (Err: 0.743 )
#
# train
# Epoch: [37]	 Loss 0.0832 (0.0215)	 acc 97.917 (99.227)
# Test	  accuracy: 87.750 (Err: 0.476 )
#
# train
# Epoch: [38]	 Loss 0.0383 (0.0211)	 acc 97.917 (99.276)
# Test	  accuracy: 87.000 (Err: 0.450 )
#
# train
# Epoch: [39]	 Loss 0.0525 (0.0184)	 acc 97.917 (99.325)
# Test	  accuracy: 80.500 (Err: 0.757 )
#
# train
# Epoch: [40]	 Loss 0.0019 (0.0257)	 acc 100.000 (99.075)
# Test	  accuracy: 90.000 (Err: 0.380 )
#
# train
# Epoch: [41]	 Loss 0.0773 (0.0171)	 acc 95.833 (99.365)
# Test	  accuracy: 85.750 (Err: 0.540 )
#
# train
# Epoch: [42]	 Loss 0.0241 (0.0197)	 acc 97.917 (99.286)
# Test	  accuracy: 81.750 (Err: 0.649 )
#
# train
# Epoch: [43]	 Loss 0.0175 (0.0179)	 acc 100.000 (99.362)
# Test	  accuracy: 85.500 (Err: 0.646 )
#
# train
# Epoch: [44]	 Loss 0.0313 (0.0240)	 acc 97.917 (99.115)
# Test	  accuracy: 79.500 (Err: 0.804 )
#
# train
# Epoch: [45]	 Loss 0.0074 (0.0197)	 acc 100.000 (99.263)
# Test	  accuracy: 86.500 (Err: 0.512 )
#
# train
# Epoch: [46]	 Loss 0.0010 (0.0153)	 acc 100.000 (99.464)
# Test	  accuracy: 84.250 (Err: 0.640 )
#
# train
# Epoch: [47]	 Loss 0.0209 (0.0187)	 acc 100.000 (99.319)
# Test	  accuracy: 87.250 (Err: 0.443 )
#
# train
# Epoch: [48]	 Loss 0.0066 (0.0217)	 acc 100.000 (99.227)
# Test	  accuracy: 90.000 (Err: 0.463 )
#
# train
# Epoch: [49]	 Loss 0.0025 (0.0161)	 acc 100.000 (99.450)
# Test	  accuracy: 81.750 (Err: 0.725 )
#
# train
# Epoch: [50]	 Loss 0.0165 (0.0177)	 acc 100.000 (99.338)
# Test	  accuracy: 79.500 (Err: 0.801 )
#
# train
# Epoch: [51]	 Loss 0.0311 (0.0193)	 acc 97.917 (99.342)
# Test	  accuracy: 81.250 (Err: 1.040 )
#
# train
# Epoch: [52]	 Loss 0.0091 (0.0171)	 acc 100.000 (99.362)
# Test	  accuracy: 88.750 (Err: 0.465 )
#
# train
# Epoch: [53]	 Loss 0.0248 (0.0148)	 acc 97.917 (99.477)
# Test	  accuracy: 88.000 (Err: 0.579 )
#
# train
# Epoch: [54]	 Loss 0.0102 (0.0180)	 acc 100.000 (99.394)
# Test	  accuracy: 82.750 (Err: 0.821 )
#
# train
# Epoch: [55]	 Loss 0.0028 (0.0232)	 acc 100.000 (99.200)
# Test	  accuracy: 79.750 (Err: 0.792 )
#
# train
# Epoch: [56]	 Loss 0.0092 (0.0142)	 acc 100.000 (99.477)
# Test	  accuracy: 85.750 (Err: 0.694 )
#
# train
# Epoch: [57]	 Loss 0.0008 (0.0230)	 acc 100.000 (99.184)
# Test	  accuracy: 91.500 (Err: 0.395 )
#
# train
# Epoch: [58]	 Loss 0.0019 (0.0170)	 acc 100.000 (99.358)
# Test	  accuracy: 89.250 (Err: 0.519 )
#
# train
# Epoch: [59]	 Loss 0.0235 (0.0163)	 acc 100.000 (99.457)
# Test	  accuracy: 88.250 (Err: 0.478 )
#
# train
# Epoch: [60]	 Loss 0.0214 (0.0159)	 acc 100.000 (99.421)
# Test	  accuracy: 86.500 (Err: 0.633 )
#
# train
# Epoch: [61]	 Loss 0.0645 (0.0195)	 acc 97.917 (99.322)
# Test	  accuracy: 85.500 (Err: 0.668 )
#
# train
# Epoch: [62]	 Loss 0.1649 (0.0165)	 acc 95.833 (99.434)
# Test	  accuracy: 86.750 (Err: 0.652 )
#
# train
# Epoch: [63]	 Loss 0.0508 (0.0261)	 acc 97.917 (99.128)
# Test	  accuracy: 81.250 (Err: 0.667 )
#
# train
# Epoch: [64]	 Loss 0.0266 (0.0166)	 acc 97.917 (99.371)
# Test	  accuracy: 87.000 (Err: 0.524 )
#
# train
# Epoch: [65]	 Loss 0.0595 (0.0200)	 acc 95.833 (99.246)
# Test	  accuracy: 81.250 (Err: 0.807 )
#
# train
# Epoch: [66]	 Loss 0.0201 (0.0233)	 acc 100.000 (99.184)
# Test	  accuracy: 88.750 (Err: 0.474 )
#
# train
# Epoch: [67]	 Loss 0.0013 (0.0201)	 acc 100.000 (99.259)
# Test	  accuracy: 87.750 (Err: 0.517 )
#
# train
# Epoch: [68]	 Loss 0.0215 (0.0205)	 acc 97.917 (99.250)
# Test	  accuracy: 78.000 (Err: 0.894 )
#
# train
# Epoch: [69]	 Loss 0.0085 (0.0111)	 acc 100.000 (99.651)
# Test	  accuracy: 86.000 (Err: 0.866 )
#
# train
# Epoch: [70]	 Loss 0.0991 (0.0205)	 acc 97.917 (99.335)
# Test	  accuracy: 85.750 (Err: 0.572 )
#
# train
# Epoch: [71]	 Loss 0.0457 (0.0164)	 acc 97.917 (99.473)
# Test	  accuracy: 88.500 (Err: 0.542 )
#
# train
# Epoch: [72]	 Loss 0.0042 (0.0194)	 acc 100.000 (99.322)
# Test	  accuracy: 87.250 (Err: 0.520 )
#
# train
# Epoch: [73]	 Loss 0.0928 (0.0110)	 acc 95.833 (99.641)
# Test	  accuracy: 85.750 (Err: 0.595 )
#
# train
# Epoch: [74]	 Loss 0.0301 (0.0183)	 acc 100.000 (99.371)
# Test	  accuracy: 88.750 (Err: 0.599 )
#
# train
# Epoch: [75]	 Loss 0.0181 (0.0200)	 acc 100.000 (99.322)
# Test	  accuracy: 78.000 (Err: 0.958 )
#
# train
# Epoch: [76]	 Loss 0.0075 (0.0219)	 acc 100.000 (99.187)
# Test	  accuracy: 87.250 (Err: 0.645 )
#
# train
# Epoch: [77]	 Loss 0.0249 (0.0154)	 acc 100.000 (99.519)
# Test	  accuracy: 86.500 (Err: 0.551 )
#
# train
# Epoch: [78]	 Loss 0.0228 (0.0202)	 acc 100.000 (99.279)
# Test	  accuracy: 90.750 (Err: 0.397 )
#
# train
# Epoch: [79]	 Loss 0.1312 (0.0169)	 acc 95.833 (99.391)
# Test	  accuracy: 74.750 (Err: 1.439 )
#
# train
# Epoch: [80]	 Loss 0.0049 (0.0145)	 acc 100.000 (99.510)
# Test	  accuracy: 83.500 (Err: 0.741 )
#
# train
# Epoch: [81]	 Loss 0.0118 (0.0152)	 acc 100.000 (99.450)
# Test	  accuracy: 70.000 (Err: 1.812 )
#
# train
# Epoch: [82]	 Loss 0.0160 (0.0205)	 acc 100.000 (99.322)
# Test	  accuracy: 87.250 (Err: 0.461 )
#
# train
# Epoch: [83]	 Loss 0.0176 (0.0199)	 acc 100.000 (99.266)
# Test	  accuracy: 84.000 (Err: 0.837 )
#
# train
# Epoch: [84]	 Loss 0.0007 (0.0208)	 acc 100.000 (99.302)
# Test	  accuracy: 87.000 (Err: 0.557 )
#
# train
# Epoch: [85]	 Loss 0.0052 (0.0126)	 acc 100.000 (99.562)
# Test	  accuracy: 86.750 (Err: 0.579 )
#
# train
# Epoch: [86]	 Loss 0.0028 (0.0190)	 acc 100.000 (99.352)
# Test	  accuracy: 85.750 (Err: 0.760 )
#
# train
# Epoch: [87]	 Loss 0.0001 (0.0170)	 acc 100.000 (99.414)
# Test	  accuracy: 81.000 (Err: 0.848 )
#
# train
# Epoch: [88]	 Loss 0.0045 (0.0113)	 acc 100.000 (99.612)
# Test	  accuracy: 86.750 (Err: 0.533 )
#
# train
# Epoch: [89]	 Loss 0.0590 (0.0209)	 acc 97.917 (99.266)
# Test	  accuracy: 85.750 (Err: 0.609 )
#
# train
# Epoch: [90]	 Loss 0.0027 (0.0174)	 acc 100.000 (99.398)
# Test	  accuracy: 89.000 (Err: 0.625 )
#
# train
# Epoch: [91]	 Loss 0.0045 (0.0157)	 acc 100.000 (99.473)
# Test	  accuracy: 88.000 (Err: 0.502 )
#
# train
# Epoch: [92]	 Loss 0.0578 (0.0188)	 acc 97.917 (99.352)
# Test	  accuracy: 86.000 (Err: 0.615 )
#
# train
# Epoch: [93]	 Loss 0.0932 (0.0214)	 acc 97.917 (99.306)
# Test	  accuracy: 86.750 (Err: 0.557 )
#
# train
# Epoch: [94]	 Loss 0.0218 (0.0179)	 acc 100.000 (99.408)
# Test	  accuracy: 85.250 (Err: 0.574 )
#
# train
# Epoch: [95]	 Loss 0.0705 (0.0163)	 acc 97.917 (99.427)
# Test	  accuracy: 89.000 (Err: 0.656 )
#
# train
# Epoch: [96]	 Loss 0.0010 (0.0194)	 acc 100.000 (99.319)
# Test	  accuracy: 86.250 (Err: 0.892 )
#
# train
# Epoch: [97]	 Loss 0.0125 (0.0169)	 acc 100.000 (99.427)
# Test	  accuracy: 89.750 (Err: 0.386 )
#
# train
# Epoch: [98]	 Loss 0.0754 (0.0163)	 acc 97.917 (99.460)
# Test	  accuracy: 83.750 (Err: 0.746 )
#
# train
# Epoch: [99]	 Loss 0.1223 (0.0161)	 acc 95.833 (99.506)
# Test	  accuracy: 81.750 (Err: 0.839 )
